# %%
#extra module
import csv
import random
import math
from collections import defaultdict, Counter
import statistics

# %%
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

# %%
#retriving students data
def retrieve_data(file):
    students_data = []
    with open(file, "r" , newline='') as f:
        key = csv.DictReader(f)             #use the data from the first row as keys for the dictionary in subsequent lines
        for i in key:                       # should treat each row as dictionary
            temp = {j:k for j,k in i.items()}
            temp['CGPA'] = float(temp['CGPA'])
            students_data.append(temp)
    return students_data

#debugging
#print(retrieve_data("records.csv"))

# %%
#uploading students data to a csv file with the assigned team
def write_teams(file, filepath):
    with open(filepath, 'w', newline = '') as f:
        writer = csv.DictWriter(f, fieldnames=["Tutorial Group", "Student ID", "School", "Name", "Gender", "CGPA", "Team Assigned"])

        writer.writeheader()

        for r in file:
            out = {k: r.get(k, "") for k in ["Tutorial Group", "Student ID", "School", "Name", "Gender", "CGPA", "Team Assigned"]}
            writer.writerow(out)

# %%
def gpa_quartile(grade : list):
    sorted_vals = sorted(grade)
    n = len(sorted_vals)
    
    def percentile(p : float):
        return max(0, min(n-1, int(math.floor(p * n))))
        
    q1 = sorted_vals[percentile(0.25)]                  # find q1, q2 (median), q3 of the sorted list
    q2 = sorted_vals[percentile(0.5)]
    q3 = sorted_vals[percentile(0.75)]
    
    def label(x):
        if x <= q1:
            return 0
        elif x <= q2:
            return 1
        elif x <= q3:
            return 2
        else:
            return 3
    return label

# %%
def mean_std(values):
    if len(values) == 0:
        return 0.0, 0.0
    if len(values) == 1:
        return values[0], 0.0
    aver = sum(values) / len(values)
    var = sum((v - aver) ** 2 for v in values) / len(values)
    return aver, math.sqrt(var)

# %%
def initial_assignment(students : list, sizes : list):

    cgpas = [s['CGPA'] for s in students]           # find all cgpas value and find the quartile value
    cgpa_value = gpa_quartile(cgpas)

    # group students by (school, gender, q value)
    buckets = defaultdict(list)                       #divide to each bucket
                                                      #each buckets contain students of same school, same gender and same gpa quartile
    for s in students:
        key = (s['School'], s['Gender'], cgpa_value(s['CGPA']))
        buckets[key].append(s)

    # sort so that large buckets go first --> ensure the large buckets are diversity to all teams
    keys_sorted = sorted(buckets.keys(), key=lambda k: len(buckets[k]), reverse=True)
    
    #10 empty teams
    teams = [[] for i in sizes]
    caps = sizes[:]                               # a copy of teams that later can be modified
    
    # round-robin assignment from each bucket
    for key in keys_sorted:
        bucket = buckets[key]
        school, gender, _q = key
        while bucket:
            # Find all teams index that still have space (caps[i] > 0)
            remaining_teams_indexes = [i for i, c in enumerate(caps) if c > 0]       #both value and index
            
            #Find the best team for students in each bucket
            def score(i):
                team = teams[i]
                count_school = sum(1 for m in team if m['School'] == school)        # +1 if a member in this team has the same school as bucket
                count_gender = sum(1 for m in team if m['Gender'] == gender)        # +1 if same gender
                return (count_school, count_gender, -caps[i])                         # if they are the same, choose the team with lower capacity. Hence, -caps[i]

            
            best = min(remaining_teams_indexes, key=score)                          #key=score means compare cnt_score first, then cnt_gender, then -caps[i]
            #add the suitable student
            student_chosen = bucket.pop()
            teams[best].append(student_chosen)
            #reduce that team’s capacity by 1
            caps[best] -= 1
    return teams

# %%
def team_penalty(team, group_mean, group_std):
    #see how many students are in this team; if the team is empty (edge case), no penalty.
    n = len(team)
    if n == 0:
        return 0.0
        
    # school majority

    sch_count = Counter([m['School'] for m in team])        #build a dictionary of how many times each school appears in the team
    top_school_count = max(sch_count.values())               #give the largest number of student from the same school
    
    majority_threshold = 2

    school_pen = 0.0                                         # if too many from the same school (>2), add the school penalty
    if top_school_count > majority_threshold:
        school_pen = (top_school_count - majority_threshold) * 50

    # gender majority
    majority_threshold = 3                                   # just like school, but the gender should be > 3
    gen_counts = Counter([m['Gender'] for m in team])
    top_gender_count = max(gen_counts.values())
    gender_pen = 0.0
    if top_gender_count > majority_threshold:
        gender_pen = (top_gender_count - majority_threshold) * 35

    # CGPA deviation penalty.
    cgpas = [m['CGPA'] for m in team]
    team_mean = sum(cgpas) / len(cgpas)              #find average cgpa of a team
    
    if group_std > 0:
        z = abs(team_mean - group_mean) / group_std     #standard deviation and normal distribution
    else:
        z = 0.0
        
    cgpa_pen = z * 70                                   #multiply by gpa penalty

    return school_pen + gender_pen + cgpa_pen

#Now, find the total penalty of all teams
def total_penalty(teams, group_mean, group_std):              
    total = 0
    for t in teams:
        total += team_penalty(t, group_mean, group_std)
    return total

# %%
def local_improvement_swaps(teams, group_mean, group_std, max_iters=2000):
    current_pen = total_penalty(teams, group_mean, group_std) 
    iters = 0
    no_improve_count = 0
    
    while iters < max_iters and no_improve_count < 500:                 #if swap 500 times without improvement, break
        iters += 1
        
        #Randomly pick two different teams.
        i, j = random.sample(range(len(teams)), 2)                  #pick 2 random teams with different indexes
     
        a = random.randrange(len(teams[i]))
        b = random.randrange(len(teams[j])) #Randomly choose one student index from team i and one from team j, to be swapped
        
        #Find penalty of 2 teams before swap
        before = team_penalty(teams[i], group_mean, group_std) + team_penalty(teams[j], group_mean, group_std)
        
        teams[i][a], teams[j][b] = teams[j][b], teams[i][a]
        
        #Find penalty of 2 teams after swqp
        after = team_penalty(teams[i], group_mean, group_std) + team_penalty(teams[j], group_mean, group_std)

        #If improve, keep the swap, else, revert back
        if after < before:
            current_pen += (after - before)
            no_improve_count = 0
        else:
            teams[i][a], teams[j][b] = teams[j][b], teams[i][a]
            no_improve_count += 1 
            #add 1 to the no_improvement_count
    return teams, current_pen

# %%
def form_teams_for_tutorial(students, team_size = 5, max_swap_iters=5000):
    
    n = 50                                   #each tutorial group has 50 students

    sizes = [5 for i in range(10)]           # create 10 teams of 5

    teams = initial_assignment(students, sizes)          #add members to 10 teams
    
    # compute group CGPA stats
    cgpas = [s['CGPA'] for s in students]               #extract all CGPA values for this tutorial group.
    group_mean, group_std = mean_std(cgpas)             #get average CGPA and standard deviation

    #improve by local swap
    teams, final_pen = local_improvement_swaps(teams, group_mean, group_std, max_iters=max_swap_iters)

    #returns a tuple of results for each tutorial group
    return teams, final_pen, group_mean, group_std

# %%
all_students = retrieve_data("records.csv") 

# Group by tutorial group
groups = defaultdict(list)
for r in all_students:
    groups[r['Tutorial Group']].append(r)

final_records = []                        # each student will include 'Team Assigned'
group_summaries = []                      
total_penalty_all = 0.0

for tg, students in sorted(groups.items()):                                    #sorted() by alphabetical order
    teams, pen, group_mean, group_std = form_teams_for_tutorial(students)
    total_penalty_all += pen                                                   #total penalty
     

    for tidx, team in enumerate(teams, start=1):
        team_id = f"{tg}_T{tidx}"
        for m in team:
            rec = {
                "Tutorial Group": tg,
                "Student ID": m['Student ID'],
                "School": m['School'],
                "Name": m['Name'],
                "Gender": m['Gender'],
                "CGPA": m['CGPA'],
                "Team Assigned": team_id
            }
            final_records.append(rec)
            
    # compute violation counts for this tutorial to track: How many teams are violating rules, How diverse each team is, Average CGPA of each team
    violating = 0
    team_diversities = []
    team_cgpa_means = []
    for team in teams:
        n = len(team)

        #Count the number of group violating the rule of max 2 members of same school per group or max 3 members of same gender per group
        top_school_count = max(Counter([m['School'] for m in team]).values())
        top_gender_count = max(Counter([m['Gender'] for m in team]).values())
        if top_school_count > 2 or top_gender_count > 3:
            violating += 1
            
        schools = [m['School'] for m in team]
        counts = Counter(schools)
        
        cgpa_mean = sum(m['CGPA'] for m in team) / n
        team_cgpa_means.append(cgpa_mean)

    #Stores all tutorial-level data for reporting later
    group_summaries.append({
        "Tutorial Group": tg,
        "Students": len(students),
        "Teams": len(teams),
        "Violating Teams": violating,
        "Group Penalty": pen,
        "Avg Team CGPA Mean": (sum(team_cgpa_means)/len(team_cgpa_means)),
        "Group CGPA Mean": group_mean,
        "Group CGPA Std": group_std
    })

# write output CSV with Team Assign column
write_teams(final_records, "teams_output.csv")

print(f"Total penalty across all groups: {total_penalty_all:.2f}")

#Summary
for s in sorted(group_summaries, key=lambda x: x["Tutorial Group"])[:]:
    print(s)
# Out:
# Total penalty across all groups: 1888.10
# {'Tutorial Group': 'G-1', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.122699288489589, 'Avg Team CGPA Mean': 4.095599999999999, 'Group CGPA Mean': 4.0956, 'Group CGPA Std': 0.12277068053896256}
# {'Tutorial Group': 'G-10', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.587083080374074, 'Avg Team CGPA Mean': 4.118, 'Group CGPA Mean': 4.118, 'Group CGPA Std': 0.1220819396962548}
# {'Tutorial Group': 'G-100', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.855649082643991, 'Avg Team CGPA Mean': 4.0942, 'Group CGPA Mean': 4.0942, 'Group CGPA Std': 0.11027402232620336}
# {'Tutorial Group': 'G-101', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.013093298452226, 'Avg Team CGPA Mean': 4.108, 'Group CGPA Mean': 4.1080000000000005, 'Group CGPA Std': 0.1397712416772492}
# {'Tutorial Group': 'G-102', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 10.753898206663408, 'Avg Team CGPA Mean': 4.100199999999999, 'Group CGPA Mean': 4.1002, 'Group CGPA Std': 0.09373345187285058}
# {'Tutorial Group': 'G-103', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.537923220440658, 'Avg Team CGPA Mean': 4.1044, 'Group CGPA Mean': 4.1044, 'Group CGPA Std': 0.1213451276318913}
# {'Tutorial Group': 'G-104', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 11.35303037208476, 'Avg Team CGPA Mean': 4.0674, 'Group CGPA Mean': 4.0674, 'Group CGPA Std': 0.08632056533642488}
# {'Tutorial Group': 'G-105', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.923894604664818, 'Avg Team CGPA Mean': 4.0922, 'Group CGPA Mean': 4.0922, 'Group CGPA Std': 0.10235799919889023}
# {'Tutorial Group': 'G-106', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 13.032371561460836, 'Avg Team CGPA Mean': 4.084200000000001, 'Group CGPA Mean': 4.0842, 'Group CGPA Std': 0.11601879158136413}
# {'Tutorial Group': 'G-107', 'Students': 50, 'Teams': 10, 'Violating Teams': 1, 'Group Penalty': 47.53201029569149, 'Avg Team CGPA Mean': 4.068, 'Group CGPA Mean': 4.0680000000000005, 'Group CGPA Std': 0.11171392035015154}
# {'Tutorial Group': 'G-108', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.179518334146213, 'Avg Team CGPA Mean': 4.0832, 'Group CGPA Mean': 4.0832, 'Group CGPA Std': 0.13593292463564524}
# {'Tutorial Group': 'G-109', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.654096135098056, 'Avg Team CGPA Mean': 4.0840000000000005, 'Group CGPA Mean': 4.084, 'Group CGPA Std': 0.10974515934655159}
# {'Tutorial Group': 'G-11', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.523750924363682, 'Avg Team CGPA Mean': 4.0722000000000005, 'Group CGPA Mean': 4.0722, 'Group CGPA Std': 0.11588425259714971}
# {'Tutorial Group': 'G-110', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 17.794028919022075, 'Avg Team CGPA Mean': 4.0776, 'Group CGPA Mean': 4.0776, 'Group CGPA Std': 0.07867807826834615}
# {'Tutorial Group': 'G-111', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.874088277903104, 'Avg Team CGPA Mean': 4.087400000000001, 'Group CGPA Mean': 4.0874, 'Group CGPA Std': 0.13512675530774798}
# {'Tutorial Group': 'G-112', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.467445633881663, 'Avg Team CGPA Mean': 4.1056, 'Group CGPA Mean': 4.1056, 'Group CGPA Std': 0.11243060081668159}
# {'Tutorial Group': 'G-113', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 2.520171377484859, 'Avg Team CGPA Mean': 4.054, 'Group CGPA Mean': 4.053999999999999, 'Group CGPA Std': 0.11110355529864921}
# {'Tutorial Group': 'G-114', 'Students': 50, 'Teams': 10, 'Violating Teams': 3, 'Group Penalty': 112.15923420614894, 'Avg Team CGPA Mean': 4.0912, 'Group CGPA Mean': 4.0912, 'Group CGPA Std': 0.11733098482498136}
# {'Tutorial Group': 'G-115', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.803811789656999, 'Avg Team CGPA Mean': 4.094799999999999, 'Group CGPA Mean': 4.0948, 'Group CGPA Std': 0.10046372479656528}
# {'Tutorial Group': 'G-116', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 3.813592684605049, 'Avg Team CGPA Mean': 4.100199999999999, 'Group CGPA Mean': 4.1002, 'Group CGPA Std': 0.13215884382060858}
# {'Tutorial Group': 'G-117', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.464656725030876, 'Avg Team CGPA Mean': 4.1086, 'Group CGPA Mean': 4.1086, 'Group CGPA Std': 0.13426853689528315}
# {'Tutorial Group': 'G-118', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.423052352381877, 'Avg Team CGPA Mean': 4.1064, 'Group CGPA Mean': 4.1064, 'Group CGPA Std': 0.12391545504899698}
# {'Tutorial Group': 'G-119', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.916649662823373, 'Avg Team CGPA Mean': 4.0972, 'Group CGPA Mean': 4.0972, 'Group CGPA Std': 0.101647233115319}
# {'Tutorial Group': 'G-12', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.217347023206471, 'Avg Team CGPA Mean': 4.117, 'Group CGPA Mean': 4.117, 'Group CGPA Std': 0.13416780537819045}
# {'Tutorial Group': 'G-120', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 10.732460462043687, 'Avg Team CGPA Mean': 4.12, 'Group CGPA Mean': 4.12, 'Group CGPA Std': 0.1304453908729626}
# {'Tutorial Group': 'G-13', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.752954893808802, 'Avg Team CGPA Mean': 4.0634, 'Group CGPA Mean': 4.0634, 'Group CGPA Std': 0.11195731329395148}
# {'Tutorial Group': 'G-14', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.499142300607183, 'Avg Team CGPA Mean': 4.077, 'Group CGPA Mean': 4.077, 'Group CGPA Std': 0.1292478239662084}
# {'Tutorial Group': 'G-15', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.778603544005604, 'Avg Team CGPA Mean': 4.0596000000000005, 'Group CGPA Mean': 4.0596, 'Group CGPA Std': 0.09913546287782188}
# {'Tutorial Group': 'G-16', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 11.531790783710035, 'Avg Team CGPA Mean': 4.0766, 'Group CGPA Mean': 4.0766, 'Group CGPA Std': 0.10926316854274368}
# {'Tutorial Group': 'G-17', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.696770283648624, 'Avg Team CGPA Mean': 4.087999999999999, 'Group CGPA Mean': 4.088, 'Group CGPA Std': 0.11923086848631101}
# {'Tutorial Group': 'G-18', 'Students': 50, 'Teams': 10, 'Violating Teams': 1, 'Group Penalty': 41.49409049859848, 'Avg Team CGPA Mean': 4.0704, 'Group CGPA Mean': 4.0704, 'Group CGPA Std': 0.10347869345908849}
# {'Tutorial Group': 'G-19', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 11.38393821367751, 'Avg Team CGPA Mean': 4.074199999999999, 'Group CGPA Mean': 4.0742, 'Group CGPA Std': 0.08854580735415993}
# {'Tutorial Group': 'G-2', 'Students': 50, 'Teams': 10, 'Violating Teams': 2, 'Group Penalty': 79.41369814157225, 'Avg Team CGPA Mean': 4.0886, 'Group CGPA Mean': 4.0886000000000005, 'Group CGPA Std': 0.08328289140033508}
# {'Tutorial Group': 'G-20', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.118045668275023, 'Avg Team CGPA Mean': 4.082800000000001, 'Group CGPA Mean': 4.0828, 'Group CGPA Std': 0.11726960390484821}
# {'Tutorial Group': 'G-21', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.2223819110384, 'Avg Team CGPA Mean': 4.0704, 'Group CGPA Mean': 4.0704, 'Group CGPA Std': 0.10322712821734412}
# {'Tutorial Group': 'G-22', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.740646576732488, 'Avg Team CGPA Mean': 4.082, 'Group CGPA Mean': 4.082, 'Group CGPA Std': 0.0975499871860576}
# {'Tutorial Group': 'G-23', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 10.806596242276981, 'Avg Team CGPA Mean': 4.078, 'Group CGPA Mean': 4.078, 'Group CGPA Std': 0.15546060594247027}
# {'Tutorial Group': 'G-24', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.684964608563336, 'Avg Team CGPA Mean': 4.0576, 'Group CGPA Mean': 4.0576, 'Group CGPA Std': 0.09829669373890455}
# {'Tutorial Group': 'G-25', 'Students': 50, 'Teams': 10, 'Violating Teams': 1, 'Group Penalty': 40.9571922707153, 'Avg Team CGPA Mean': 4.0914, 'Group CGPA Mean': 4.0914, 'Group CGPA Std': 0.1316056229801752}
# {'Tutorial Group': 'G-26', 'Students': 50, 'Teams': 10, 'Violating Teams': 1, 'Group Penalty': 42.502584243211686, 'Avg Team CGPA Mean': 4.0808, 'Group CGPA Mean': 4.0808, 'Group CGPA Std': 0.11196142192737636}
# {'Tutorial Group': 'G-27', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 13.007179613141368, 'Avg Team CGPA Mean': 4.074599999999999, 'Group CGPA Mean': 4.0746, 'Group CGPA Std': 0.13346475190101692}
# {'Tutorial Group': 'G-28', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.706012433842686, 'Avg Team CGPA Mean': 4.0732, 'Group CGPA Mean': 4.0732, 'Group CGPA Std': 0.1002085824667728}
# {'Tutorial Group': 'G-29', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.048963328697548, 'Avg Team CGPA Mean': 4.0838, 'Group CGPA Mean': 4.0838, 'Group CGPA Std': 0.11448825267249033}
# {'Tutorial Group': 'G-3', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 30.80971814753324, 'Avg Team CGPA Mean': 4.105, 'Group CGPA Mean': 4.105, 'Group CGPA Std': 0.1817608318642936}
# {'Tutorial Group': 'G-30', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 3.632918623250035, 'Avg Team CGPA Mean': 4.0964, 'Group CGPA Mean': 4.0964, 'Group CGPA Std': 0.12331682772436209}
# {'Tutorial Group': 'G-31', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.2996156603996125, 'Avg Team CGPA Mean': 4.1054, 'Group CGPA Mean': 4.1054, 'Group CGPA Std': 0.1479352561088803}
# {'Tutorial Group': 'G-32', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 2.5854164608808246, 'Avg Team CGPA Mean': 4.0842, 'Group CGPA Mean': 4.0842, 'Group CGPA Std': 0.0974697901916281}
# {'Tutorial Group': 'G-33', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.906138939648507, 'Avg Team CGPA Mean': 4.1088000000000005, 'Group CGPA Mean': 4.1088, 'Group CGPA Std': 0.1257559541333928}
# {'Tutorial Group': 'G-34', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.787898264736016, 'Avg Team CGPA Mean': 4.0886000000000005, 'Group CGPA Mean': 4.0886000000000005, 'Group CGPA Std': 0.11151699422061195}
# {'Tutorial Group': 'G-35', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 12.78118332445402, 'Avg Team CGPA Mean': 4.1091999999999995, 'Group CGPA Mean': 4.1092, 'Group CGPA Std': 0.09639170088757643}
# {'Tutorial Group': 'G-36', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.286957803901238, 'Avg Team CGPA Mean': 4.075799999999999, 'Group CGPA Mean': 4.0758, 'Group CGPA Std': 0.11155429171484166}
# {'Tutorial Group': 'G-37', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.784830636007495, 'Avg Team CGPA Mean': 4.1268, 'Group CGPA Mean': 4.1268, 'Group CGPA Std': 0.17264344760227648}
# {'Tutorial Group': 'G-38', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 12.1082127993579, 'Avg Team CGPA Mean': 4.0902, 'Group CGPA Mean': 4.090199999999999, 'Group CGPA Std': 0.12949888030403967}
# {'Tutorial Group': 'G-39', 'Students': 50, 'Teams': 10, 'Violating Teams': 2, 'Group Penalty': 76.07017083502426, 'Avg Team CGPA Mean': 4.0774, 'Group CGPA Mean': 4.0774, 'Group CGPA Std': 0.0968671254864105}
# {'Tutorial Group': 'G-4', 'Students': 50, 'Teams': 10, 'Violating Teams': 4, 'Group Penalty': 147.23034019034372, 'Avg Team CGPA Mean': 4.079, 'Group CGPA Mean': 4.079, 'Group CGPA Std': 0.09681425514871247}
# {'Tutorial Group': 'G-40', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.0572592629016455, 'Avg Team CGPA Mean': 4.1026, 'Group CGPA Mean': 4.1026, 'Group CGPA Std': 0.13886410623339634}
# {'Tutorial Group': 'G-41', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.31984361625918, 'Avg Team CGPA Mean': 4.0966000000000005, 'Group CGPA Mean': 4.0966000000000005, 'Group CGPA Std': 0.10633174502471028}
# {'Tutorial Group': 'G-42', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.024779864075114, 'Avg Team CGPA Mean': 4.0968, 'Group CGPA Mean': 4.0968, 'Group CGPA Std': 0.15352446059178967}
# {'Tutorial Group': 'G-43', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.466620012195801, 'Avg Team CGPA Mean': 4.0806, 'Group CGPA Mean': 4.0806000000000004, 'Group CGPA Std': 0.0787504920619548}
# {'Tutorial Group': 'G-44', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.460057405133184, 'Avg Team CGPA Mean': 4.1052, 'Group CGPA Mean': 4.1052, 'Group CGPA Std': 0.10402384342063126}
# {'Tutorial Group': 'G-45', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.5563660888814494, 'Avg Team CGPA Mean': 4.0638, 'Group CGPA Mean': 4.0638, 'Group CGPA Std': 0.11061446560011945}
# {'Tutorial Group': 'G-46', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 23.085999524144658, 'Avg Team CGPA Mean': 4.058, 'Group CGPA Mean': 4.058, 'Group CGPA Std': 0.16979988221432896}
# {'Tutorial Group': 'G-47', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.36591601260604, 'Avg Team CGPA Mean': 4.058400000000001, 'Group CGPA Mean': 4.0584, 'Group CGPA Std': 0.10261305959769448}
# {'Tutorial Group': 'G-48', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.941090985324438, 'Avg Team CGPA Mean': 4.1156, 'Group CGPA Mean': 4.1156, 'Group CGPA Std': 0.13600235292082266}
# {'Tutorial Group': 'G-49', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.60554563157464, 'Avg Team CGPA Mean': 4.082, 'Group CGPA Mean': 4.082, 'Group CGPA Std': 0.09761147473529941}
# {'Tutorial Group': 'G-5', 'Students': 50, 'Teams': 10, 'Violating Teams': 2, 'Group Penalty': 80.49578561969994, 'Avg Team CGPA Mean': 4.077800000000001, 'Group CGPA Mean': 4.0778, 'Group CGPA Std': 0.1280513959314775}
# {'Tutorial Group': 'G-50', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.6211508248698685, 'Avg Team CGPA Mean': 4.1091999999999995, 'Group CGPA Mean': 4.1092, 'Group CGPA Std': 0.13961146084759665}
# {'Tutorial Group': 'G-51', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 10.938418027096635, 'Avg Team CGPA Mean': 4.103, 'Group CGPA Mean': 4.103, 'Group CGPA Std': 0.15358710883404247}
# {'Tutorial Group': 'G-52', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.946895204726973, 'Avg Team CGPA Mean': 4.069, 'Group CGPA Mean': 4.069, 'Group CGPA Std': 0.12091732712891069}
# {'Tutorial Group': 'G-53', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.061641577223032, 'Avg Team CGPA Mean': 4.077, 'Group CGPA Mean': 4.077, 'Group CGPA Std': 0.09269843580125829}
# {'Tutorial Group': 'G-54', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.085577380643151, 'Avg Team CGPA Mean': 4.1152, 'Group CGPA Mean': 4.1152, 'Group CGPA Std': 0.12882918923908518}
# {'Tutorial Group': 'G-55', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 12.912135635246255, 'Avg Team CGPA Mean': 4.0936, 'Group CGPA Mean': 4.0936, 'Group CGPA Std': 0.09107711018691804}
# {'Tutorial Group': 'G-56', 'Students': 50, 'Teams': 10, 'Violating Teams': 1, 'Group Penalty': 42.36630838214877, 'Avg Team CGPA Mean': 4.0664, 'Group CGPA Mean': 4.0664, 'Group CGPA Std': 0.09882833601756125}
# {'Tutorial Group': 'G-57', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.863159853730703, 'Avg Team CGPA Mean': 4.053800000000001, 'Group CGPA Mean': 4.0538, 'Group CGPA Std': 0.0852968932611265}
# {'Tutorial Group': 'G-58', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 3.3909203588906838, 'Avg Team CGPA Mean': 4.1064, 'Group CGPA Mean': 4.1064, 'Group CGPA Std': 0.13211752344030672}
# {'Tutorial Group': 'G-59', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 17.264811587163138, 'Avg Team CGPA Mean': 4.0744, 'Group CGPA Mean': 4.0744, 'Group CGPA Std': 0.15244881108096586}
# {'Tutorial Group': 'G-6', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.710319458658779, 'Avg Team CGPA Mean': 4.0984, 'Group CGPA Mean': 4.0984, 'Group CGPA Std': 0.14266548286113218}
# {'Tutorial Group': 'G-60', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.264207619176865, 'Avg Team CGPA Mean': 4.0996, 'Group CGPA Mean': 4.0996, 'Group CGPA Std': 0.10276108212742806}
# {'Tutorial Group': 'G-61', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.503589948350425, 'Avg Team CGPA Mean': 4.074, 'Group CGPA Mean': 4.074, 'Group CGPA Std': 0.1119464157532522}
# {'Tutorial Group': 'G-62', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.423346856073447, 'Avg Team CGPA Mean': 4.0638, 'Group CGPA Mean': 4.0638, 'Group CGPA Std': 0.10184085624149083}
# {'Tutorial Group': 'G-63', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 12.333722733769262, 'Avg Team CGPA Mean': 4.0768, 'Group CGPA Mean': 4.0768, 'Group CGPA Std': 0.09988873810395245}
# {'Tutorial Group': 'G-64', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.476488880743954, 'Avg Team CGPA Mean': 4.0962000000000005, 'Group CGPA Mean': 4.0962, 'Group CGPA Std': 0.1093231905864442}
# {'Tutorial Group': 'G-65', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.649184379483272, 'Avg Team CGPA Mean': 4.091600000000001, 'Group CGPA Mean': 4.091600000000001, 'Group CGPA Std': 0.09636098795674523}
# {'Tutorial Group': 'G-66', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.646173750203808, 'Avg Team CGPA Mean': 4.1084, 'Group CGPA Mean': 4.1084, 'Group CGPA Std': 0.11901865400011886}
# {'Tutorial Group': 'G-67', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.290864343575395, 'Avg Team CGPA Mean': 4.089, 'Group CGPA Mean': 4.0889999999999995, 'Group CGPA Std': 0.10131633629380805}
# {'Tutorial Group': 'G-68', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.949963556586349, 'Avg Team CGPA Mean': 4.077, 'Group CGPA Mean': 4.077, 'Group CGPA Std': 0.11764777940955791}
# {'Tutorial Group': 'G-69', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 11.901431977183648, 'Avg Team CGPA Mean': 4.108, 'Group CGPA Mean': 4.1080000000000005, 'Group CGPA Std': 0.09410632284814875}
# {'Tutorial Group': 'G-7', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 3.902551623990705, 'Avg Team CGPA Mean': 4.091800000000001, 'Group CGPA Mean': 4.0918, 'Group CGPA Std': 0.12914627365897938}
# {'Tutorial Group': 'G-70', 'Students': 50, 'Teams': 10, 'Violating Teams': 2, 'Group Penalty': 75.87304098026297, 'Avg Team CGPA Mean': 4.094199999999999, 'Group CGPA Mean': 4.0942, 'Group CGPA Std': 0.08581584935196995}
# {'Tutorial Group': 'G-71', 'Students': 50, 'Teams': 10, 'Violating Teams': 1, 'Group Penalty': 38.07098368009463, 'Avg Team CGPA Mean': 4.1015999999999995, 'Group CGPA Mean': 4.1015999999999995, 'Group CGPA Std': 0.1458815958234623}
# {'Tutorial Group': 'G-72', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.763198221672761, 'Avg Team CGPA Mean': 4.1024, 'Group CGPA Mean': 4.1024, 'Group CGPA Std': 0.09405445231354019}
# {'Tutorial Group': 'G-73', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 11.192554174484851, 'Avg Team CGPA Mean': 4.0866, 'Group CGPA Mean': 4.086600000000001, 'Group CGPA Std': 0.08755820920964524}
# {'Tutorial Group': 'G-74', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.822284465382207, 'Avg Team CGPA Mean': 4.0826, 'Group CGPA Mean': 4.0826, 'Group CGPA Std': 0.10099128675286795}
# {'Tutorial Group': 'G-75', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 3.7772620052231427, 'Avg Team CGPA Mean': 4.0838, 'Group CGPA Mean': 4.0838, 'Group CGPA Std': 0.133429981638311}
# {'Tutorial Group': 'G-76', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.373742211844171, 'Avg Team CGPA Mean': 4.0984, 'Group CGPA Mean': 4.0984, 'Group CGPA Std': 0.09113418677971515}
# {'Tutorial Group': 'G-77', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 7.050477312011969, 'Avg Team CGPA Mean': 4.0924, 'Group CGPA Mean': 4.0924000000000005, 'Group CGPA Std': 0.12708359453525067}
# {'Tutorial Group': 'G-78', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.829125201936847, 'Avg Team CGPA Mean': 4.0676, 'Group CGPA Mean': 4.0676, 'Group CGPA Std': 0.11416759610327272}
# {'Tutorial Group': 'G-79', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.504854702399339, 'Avg Team CGPA Mean': 4.0994, 'Group CGPA Mean': 4.0994, 'Group CGPA Std': 0.09218264478740021}
# {'Tutorial Group': 'G-8', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.59476544383905, 'Avg Team CGPA Mean': 4.0906, 'Group CGPA Mean': 4.0906, 'Group CGPA Std': 0.1050982397569056}
# {'Tutorial Group': 'G-80', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 5.998723007944448, 'Avg Team CGPA Mean': 4.1018, 'Group CGPA Mean': 4.1018, 'Group CGPA Std': 0.12602682254186995}
# {'Tutorial Group': 'G-81', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.646402759805895, 'Avg Team CGPA Mean': 4.0998, 'Group CGPA Mean': 4.0998, 'Group CGPA Std': 0.10847100995196829}
# {'Tutorial Group': 'G-82', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.939504469722875, 'Avg Team CGPA Mean': 4.0728, 'Group CGPA Mean': 4.0728, 'Group CGPA Std': 0.12104610691798401}
# {'Tutorial Group': 'G-83', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 13.330835331714047, 'Avg Team CGPA Mean': 4.0952, 'Group CGPA Mean': 4.0952, 'Group CGPA Std': 0.09241731439508512}
# {'Tutorial Group': 'G-84', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.796050174411885, 'Avg Team CGPA Mean': 4.109, 'Group CGPA Mean': 4.109, 'Group CGPA Std': 0.11141364368873327}
# {'Tutorial Group': 'G-85', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.940706172831341, 'Avg Team CGPA Mean': 4.1274, 'Group CGPA Mean': 4.1274, 'Group CGPA Std': 0.11295680590384974}
# {'Tutorial Group': 'G-86', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.174333700119371, 'Avg Team CGPA Mean': 4.111, 'Group CGPA Mean': 4.111000000000001, 'Group CGPA Std': 0.11988744721612846}
# {'Tutorial Group': 'G-87', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.529749427988568, 'Avg Team CGPA Mean': 4.1186, 'Group CGPA Mean': 4.1186, 'Group CGPA Std': 0.12473988936984033}
# {'Tutorial Group': 'G-88', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 11.76605613574933, 'Avg Team CGPA Mean': 4.0852, 'Group CGPA Mean': 4.0851999999999995, 'Group CGPA Std': 0.09518907500338473}
# {'Tutorial Group': 'G-89', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.487838357143032, 'Avg Team CGPA Mean': 4.0634, 'Group CGPA Mean': 4.0634, 'Group CGPA Std': 0.13102076171355445}
# {'Tutorial Group': 'G-9', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 4.681548941292052, 'Avg Team CGPA Mean': 4.0798000000000005, 'Group CGPA Mean': 4.0798000000000005, 'Group CGPA Std': 0.10765667652310287}
# {'Tutorial Group': 'G-90', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 10.812985144388279, 'Avg Team CGPA Mean': 4.0766, 'Group CGPA Mean': 4.0766, 'Group CGPA Std': 0.11652656349519623}
# {'Tutorial Group': 'G-91', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.219115129893506, 'Avg Team CGPA Mean': 4.085, 'Group CGPA Mean': 4.085, 'Group CGPA Std': 0.10220078277586726}
# {'Tutorial Group': 'G-92', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.484408514354209, 'Avg Team CGPA Mean': 4.099600000000001, 'Group CGPA Mean': 4.0996, 'Group CGPA Std': 0.10363319931373347}
# {'Tutorial Group': 'G-93', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 8.976712586884071, 'Avg Team CGPA Mean': 4.1314, 'Group CGPA Mean': 4.1314, 'Group CGPA Std': 0.1528399162522671}
# {'Tutorial Group': 'G-94', 'Students': 50, 'Teams': 10, 'Violating Teams': 1, 'Group Penalty': 43.557165955969694, 'Avg Team CGPA Mean': 4.0852, 'Group CGPA Mean': 4.0851999999999995, 'Group CGPA Std': 0.11125178650250973}
# {'Tutorial Group': 'G-95', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 10.373659990295492, 'Avg Team CGPA Mean': 4.0672, 'Group CGPA Mean': 4.0672, 'Group CGPA Std': 0.1457537649599488}
# {'Tutorial Group': 'G-96', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 6.001186576387284, 'Avg Team CGPA Mean': 4.0736, 'Group CGPA Mean': 4.0736, 'Group CGPA Std': 0.11197785495355765}
# {'Tutorial Group': 'G-97', 'Students': 50, 'Teams': 10, 'Violating Teams': 4, 'Group Penalty': 144.0640456827121, 'Avg Team CGPA Mean': 4.0762, 'Group CGPA Mean': 4.0762, 'Group CGPA Std': 0.12401435400791312}
# {'Tutorial Group': 'G-98', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 9.261576823178768, 'Avg Team CGPA Mean': 4.086, 'Group CGPA Mean': 4.085999999999999, 'Group CGPA Std': 0.12092973166264774}
# {'Tutorial Group': 'G-99', 'Students': 50, 'Teams': 10, 'Violating Teams': 0, 'Group Penalty': 10.441498435909798, 'Avg Team CGPA Mean': 4.0638, 'Group CGPA Mean': 4.0638, 'Group CGPA Std': 0.09653786821760672}
