# %%
# First, the program groups them by tutorial group, since teams can only be formed within the same class. 
# Within each tutorial group, the students are sorted from highest to lowest CGPA. 
# The students are then separated into male and female lists to help maintain gender balance later.
# Create 10 empty list for each group. The program assigns students one by one from the GPA-based lists, checking both school and gender conditions.
# Before adding a student, the program checks whether a team already has two members from the same school. If it does, that team is skipped and the program looks for another one.
# After all students are allocated, each is labelled with corresponding team number.

#Forming group (by school)
 group = [ ]
 temp_school = [ ]
for i in range(5):
  student_school = school.random()
  while temp_school.count(student_school) == 2:
   student_school = school.random()
  temp_school.append(student_school)
  group.append(studentID)


#Solve for gender
# no more than 3 of the same gender

gender = {studentID : gender_value}      # dictionary of each student’s gender
temp_gender = [] 


for i in range(5):
  student_gender = gender.random()
  while temp_gender.count(student_gender) == 3:
   student_gender = gender.random()
  temp_gender.append(student_gender)
  group.append(studentID)
GPA = {studentID : GPA_value}                       # dictionary of each student’s GPA
sorted_GPA = sort(GPA by descending order)      
# divide into 5 small grps
GPA1 = sorted_GPA[0:10]
GPA2 = sorted_GPA[10:20]
GPA3 = sorted_GPA[20:30]
GPA4 = sorted_GPA[30:40]
GPA5 = sorted_GPA[40:50]

team = []                                          
team.append(GPA1.random())                     
team.append(GPA2.random())
team.append(GPA3.random())
team.append(GPA4.random())
team.append(GPA5.random())
#need to remove selected students from gpa dict so they won’t be picked again


#Combine all conditions
team = []                                           
temp_team = []                                 
temp_school = []                   
temp_gender = []            

while number_of_teams < 10:                          # repeat until all teams are formed
    student = random_student_from_GPAgrps()      

    # check if this student can join the team
    if temp_school.count(student.school) < 2 and temp_gender.count(student.gender) < 3:
        temp_team.append(student)                    
        temp_school.append(student.school)           
        temp_gender.append(student.gender)         
    if length(temp_team) == 5:             #max 5 per grp
        team.append(temp_team)             # add extras final list of teams
